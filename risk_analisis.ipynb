# %% [markdown]
# Выводы по каждой категории которые у нас есть:
# **Категория 0:**
# Количество заказов = 81

# %% [markdown]
# Количество заказанных товаров по годам

# %%
years_avg
# Out:
#     product_category  years       qty
# 0                  0   2020       7.0
# 1                  0   2022      88.0
# 2                  0   2023    1063.0
# 3                  0   2024     733.0
# 4                  0   2025     650.0
# 5                  1   2021       1.0
# 6                  1   2022       2.0
# 7                  1   2023       3.0
# 8                  1   2024       3.0
# 9                  1   2025       3.0
# 10                 2   2020      33.0
# 11                 2   2021      50.0
# 12                 2   2022      70.0
# 13                 2   2023    1960.0
# 14                 2   2024    7007.0
# 15                 2   2025   10802.0
# 16                 3   2020    3240.0
# 17                 3   2021   10944.0
# 18                 3   2022  197396.0
# 19                 3   2023  182377.0
# 20                 3   2024   94820.0
# 21                 3   2025      24.0
# 22                 4   2020    1364.0
# 23                 4   2021    2869.0
# ...

# %%
years_avg
# Out:
#     product_category  years  count_orders
# 0                  0   2022             7
# 1                  0   2023             8
# 2                  0   2024            45
# 3                  0   2025            18
# 4                  1   2020            19
# 5                  1   2021            35
# 6                  1   2022            21
# 7                  1   2023             8
# 8                  1   2024            12
# 9                  1   2025            26
# 10                 2   2020            23
# 11                 2   2021             4
# 12                 2   2023            25
# 13                 2   2024            85
# 14                 2   2025           108
# 15                 3   2020          2264
# 16                 3   2021          1637
# 17                 3   2022          8461
# 18                 3   2023         19446
# 19                 3   2024         24633
# 20                 3   2025          9931
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
